# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
from helpers.dataset import dataset_experiments, compute_spectrum
from IPython.display import Video
# %load_ext autoreload
# %autoreload 2

# %%
common_folder = '/scratch/cimes/cz3321/MOM6/experiments/double_gyre/R5_sensitivity'
# Attenuation
pct_u=np.arange(0.8,1.3,0.1)
pct_l=np.arange(1.6,2.1,0.1)
member_num=10
exps1 = []
for u in pct_u*100:
    uint = round(u)
    for l in pct_l*100:
        lint = round(l)
        globals()['exps'+str(uint)+str(lint)] = [None]*member_num
        for i in range(1,member_num+1):
            globals()['exps'+str(uint)+str(lint)][i-1] = \
                'U' + '{:0>3d}'.format(uint) + 'L' + '{:0>3d}'.format(lint) \
                    + '_m' + '{:0>3d}'.format(i)
        exps1 +=  [globals()['exps'+str(uint)+str(lint)]]
# Refrence
exps0 = ['R5','R32']
exps = []
for i in range(len(exps1)): exps += exps1[i]
exps = exps+exps0
print(exps)
# Out:
# ['U070L160_m001', 'U070L160_m002', 'U070L160_m003', 'U070L160_m004', 'U070L160_m005', 'U070L160_m006', 'U070L160_m007', 'U070L160_m008', 'U070L160_m009', 'U070L160_m010', 'U070L170_m001', 'U070L170_m002', 'U070L170_m003', 'U070L170_m004', 'U070L170_m005', 'U070L170_m006', 'U070L170_m007', 'U070L170_m008', 'U070L170_m009', 'U070L170_m010', 'U070L180_m001', 'U070L180_m002', 'U070L180_m003', 'U070L180_m004', 'U070L180_m005', 'U070L180_m006', 'U070L180_m007', 'U070L180_m008', 'U070L180_m009', 'U070L180_m010', 'U070L190_m001', 'U070L190_m002', 'U070L190_m003', 'U070L190_m004', 'U070L190_m005', 'U070L190_m006', 'U070L190_m007', 'U070L190_m008', 'U070L190_m009', 'U070L190_m010', 'U070L200_m001', 'U070L200_m002', 'U070L200_m003', 'U070L200_m004', 'U070L200_m005', 'U070L200_m006', 'U070L200_m007', 'U070L200_m008', 'U070L200_m009', 'U070L200_m010', 'U080L160_m001', 'U080L160_m002', 'U080L160_m003', 'U080L160_m004', 'U080L160_m005', 'U080L160_m006', 'U080L160_m007', 'U080L160_m008', 'U080L160_m
# ...

# %%
ds = dataset_experiments(common_folder, exps)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.conda/envs/conda_forpy2/lib/python3.9/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     198             try:
# --> 199                 file = self._cache[self._key]
#     200             except KeyError:
#
# ~/.conda/envs/conda_forpy2/lib/python3.9/site-packages/xarray/backends/lru_cache.py in __getitem__(self, key)
#      52         with self._lock:
# ---> 53             value = self._cache[key]
#      54             self._cache.move_to_end(key)
#
# KeyError: [<function _open_scipy_netcdf at 0x14e53b0b9820>, ('/scratch/cimes/cz3321/MOM6/experiments/double_gyre/R5_sensitivity/U070L180_m001/ocean.stats.nc',), 'r', (('mmap', None), ('version', 2))]
#
# During handling of the above exception, another exception occurred:
#
# ...

# %% [markdown]
# # Attenuation of parameterization

# %%
ds.plot_KE_sensitivity_2D(pct_u,pct_l,exps1,exps0)
# Out:
# Fitting location: 0.8625999999999932 1.7629999999999821
