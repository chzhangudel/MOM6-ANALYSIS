# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
from helpers.dataset import dataset_experiments, compute_spectrum
from IPython.display import Video
# %load_ext autoreload
# %autoreload 2

# %%
common_folder = '/scratch/cimes/cz3321/MOM6/experiments/double_gyre/R4_sensitivity'
# Attenuation
pct_u=np.arange(0.5,1.0,0.1)
pct_l=np.arange(1.3,1.8,0.1)
member_num=10
exps1 = []
for u in pct_u*100:
    uint = round(u)
    for l in pct_l*100:
        lint = round(l)
        globals()['exps'+str(uint)+str(lint)] = [None]*member_num
        for i in range(1,member_num+1):
            globals()['exps'+str(uint)+str(lint)][i-1] = \
                'U' + '{:0>3d}'.format(uint) + 'L' + '{:0>3d}'.format(lint) \
                    + '_m' + '{:0>3d}'.format(i)
        exps1 +=  [globals()['exps'+str(uint)+str(lint)]]
# Refrence
exps0 = ['R4','R32']
exps = []
for i in range(len(exps1)): exps += exps1[i]
exps = exps+exps0
print(exps)
# Out:
# ['U050L130_m001', 'U050L130_m002', 'U050L130_m003', 'U050L130_m004', 'U050L130_m005', 'U050L130_m006', 'U050L130_m007', 'U050L130_m008', 'U050L130_m009', 'U050L130_m010', 'U050L140_m001', 'U050L140_m002', 'U050L140_m003', 'U050L140_m004', 'U050L140_m005', 'U050L140_m006', 'U050L140_m007', 'U050L140_m008', 'U050L140_m009', 'U050L140_m010', 'U050L150_m001', 'U050L150_m002', 'U050L150_m003', 'U050L150_m004', 'U050L150_m005', 'U050L150_m006', 'U050L150_m007', 'U050L150_m008', 'U050L150_m009', 'U050L150_m010', 'U050L160_m001', 'U050L160_m002', 'U050L160_m003', 'U050L160_m004', 'U050L160_m005', 'U050L160_m006', 'U050L160_m007', 'U050L160_m008', 'U050L160_m009', 'U050L160_m010', 'U050L170_m001', 'U050L170_m002', 'U050L170_m003', 'U050L170_m004', 'U050L170_m005', 'U050L170_m006', 'U050L170_m007', 'U050L170_m008', 'U050L170_m009', 'U050L170_m010', 'U060L130_m001', 'U060L130_m002', 'U060L130_m003', 'U060L130_m004', 'U060L130_m005', 'U060L130_m006', 'U060L130_m007', 'U060L130_m008', 'U060L130_m009', 'U060L130_m010', 'U060L140_m001', 'U060L140_m002', 'U060L140_m003', 'U060L140_m004', 'U060L140_m005', 'U060L140_m006', 'U060L140_m007', 'U060L140_m008', 'U060L140_m009', 'U060L140_m010', 'U060L150_m001', 'U060L150_m002', 'U060L150_m003', 'U060L150_m004', 'U060L150_m005', 'U060L150_m006', 'U060L150_m007', 'U060L150_m008', 'U060L150_m009', 'U060L150_m010', 'U060L160_m001', 'U060L160_m002', 'U060L160_m003', 'U060L160_m004', 'U060L160_m005', 'U060L160_m006', 'U060L160_m007', 'U060L160_m008', 'U060L160_m009', 'U060L160_m010', 'U060L170_m001', 'U060L170_m002', 'U060L170_m003', 'U060L170_m004', 'U060L170_m005', 'U060L170_m006', 'U060L170_m007', 'U060L170_m008', 'U060L170_m009', 'U060L170_m010', 'U070L130_m001', 'U070L130_m002', 'U070L130_m003', 'U070L130_m004', 'U070L130_m005', 'U070L130_m006', 'U070L130_m007', 'U070L130_m008', 'U070L130_m009', 'U070L130_m010', 'U070L140_m001', 'U070L140_m002', 'U070L140_m003', 'U070L140_m004', 'U070L140_m005', 'U070L140_m006', 'U070L140_m007', 'U070L140_m008', 'U070L140_m009', 'U070L140_m010', 'U070L150_m001', 'U070L150_m002', 'U070L150_m003', 'U070L150_m004', 'U070L150_m005', 'U070L150_m006', 'U070L150_m007', 'U070L150_m008', 'U070L150_m009', 'U070L150_m010', 'U070L160_m001', 'U070L160_m002', 'U070L160_m003', 'U070L160_m004', 'U070L160_m005', 'U070L160_m006', 'U070L160_m007', 'U070L160_m008', 'U070L160_m009', 'U070L160_m010', 'U070L170_m001', 'U070L170_m002', 'U070L170_m003', 'U070L170_m004', 'U070L170_m005', 'U070L170_m006', 'U070L170_m007', 'U070L170_m008', 'U070L170_m009', 'U070L170_m010', 'U080L130_m001', 'U080L130_m002', 'U080L130_m003', 'U080L130_m004', 'U080L130_m005', 'U080L130_m006', 'U080L130_m007', 'U080L130_m008', 'U080L130_m009', 'U080L130_m010', 'U080L140_m001', 'U080L140_m002', 'U080L140_m003', 'U080L140_m004', 'U080L140_m005', 'U080L140_m006', 'U080L140_m007', 'U080L140_m008', 'U080L140_m009', 'U080L140_m010', 'U080L150_m001', 'U080L150_m002', 'U080L150_m003', 'U080L150_m004', 'U080L150_m005', 'U080L150_m006', 'U080L150_m007', 'U080L150_m008', 'U080L150_m009', 'U080L150_m010', 'U080L160_m001', 'U080L160_m002', 'U080L160_m003', 'U080L160_m004', 'U080L160_m005', 'U080L160_m006', 'U080L160_m007', 'U080L160_m008', 'U080L160_m009', 'U080L160_m010', 'U080L170_m001', 'U080L170_m002', 'U080L170_m003', 'U080L170_m004', 'U080L170_m005', 'U080L170_m006', 'U080L170_m007', 'U080L170_m008', 'U080L170_m009', 'U080L170_m010', 'U090L130_m001', 'U090L130_m002', 'U090L130_m003', 'U090L130_m004', 'U090L130_m005', 'U090L130_m006', 'U090L130_m007', 'U090L130_m008', 'U090L130_m009', 'U090L130_m010', 'U090L140_m001', 'U090L140_m002', 'U090L140_m003', 'U090L140_m004', 'U090L140_m005', 'U090L140_m006', 'U090L140_m007', 'U090L140_m008', 'U090L140_m009', 'U090L140_m010', 'U090L150_m001', 'U090L150_m002', 'U090L150_m003', 'U090L150_m004', 'U090L150_m005', 'U090L150_m006', 'U090L150_m007', 'U090L150_m008', 'U090L150_m009', 'U090L150_m010', 'U090L160_m001', 'U090L160_m002', 'U090L160_m003', 'U090L160_m004', 'U090L160_m005', 'U09 ...

# %%
ds = dataset_experiments(common_folder, exps)

# %% [markdown]
# # Attenuation of parameterization

# %%
ds.plot_KE_sensitivity_2D(pct_u,pct_l,exps1,exps0)
# Out:
# Fitting location: 0.7712999999999701 1.509999999999977
